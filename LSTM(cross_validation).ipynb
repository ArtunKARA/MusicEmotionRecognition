# %% [markdown]
# <a href="https://colab.research.google.com/github/ArtunKARA/MusicEmotionRecognition/blob/main/LSTM(cross_validation).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ortam Kurulumu ve Gerekli Kütüphanelerin Yüklenmesi

# %%
# Gerekli kütüphanelerin yüklenmesi
# !pip install librosa
# !pip install tensorflow
# !pip install scikit-learn

import traceback

import os
import numpy as np
import pandas as pd
import librosa
import librosa.display
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, roc_auc_score, roc_curve, confusion_matrix, matthews_corrcoef, auc
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# Verilerin Yüklenmesi ve İşlenmesi

# %%
from google.colab import drive
drive.mount('/content/drive')

agresif_muzikler = '/content/drive/My Drive/Music Data/Agresif'
huzunlu_muzikler = '/content/drive/My Drive/Music Data/Hüzünlü'
neseli_muzikler = '/content/drive/My Drive/Music Data/Neşeli'

# Ses dosyalarını ve etiketlerini yükleyin
def load_data(klasor_yolu, label):
    X = []
    y = []
    for dosya in os.listdir(klasor_yolu):
        dosya_yolu = os.path.join(klasor_yolu, dosya)
        data, sample_rate = librosa.load(dosya_yolu)
        mels = librosa.feature.melspectrogram(y=data, sr=sample_rate)
        X.append(mels.T)  # .T ile transpose ederek (time, features) şekline getiriyoruz
        y.append(label)
    return X, y

# Verilerin yüklenmesi
X_agresif, y_agresif = load_data(agresif_muzikler, 'Agresif')
X_huzunlu, y_huzunlu = load_data(huzunlu_muzikler, 'Hüzünlü')
X_neseli, y_neseli = load_data(neseli_muzikler, 'Neşeli')

# Verileri birleştirin
X = X_agresif + X_huzunlu + X_neseli
y = y_agresif + y_huzunlu + y_neseli

# Etiketleri sayısal değerlere dönüştürün
le = LabelEncoder()
y = le.fit_transform(y)

# Pad sequences to have the same length
X_padded = pad_sequences(X, padding='post', dtype='float32')

# NumPy array'e dönüştürün
X_padded = np.array(X_padded)
y = np.array(y)

# Eğitim ve test setlerine ayırın
X_train, X_test, y_train, y_test = train_test_split(X_padded, y, test_size=0.2, random_state=42)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1301
#   warnings.warn(

# %% [markdown]
# Modelin Oluşturulması ve Eğitilmesi

# %%
from sklearn.model_selection import KFold
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from keras.preprocessing.sequence import pad_sequences

# Veri kümenizi K-fold cross validation için hazırlayın
kf = KFold(n_splits=5, shuffle=True)  # 5 parçaya ayırarak shuffle ederek

# Eğitim ve test setleri üzerinde K-fold cross validation yapın
for train_index, test_index in kf.split(X_padded):
    X_train, X_test = X_padded[train_index], X_padded[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Modeli tanımlayın
    model = Sequential()
    model.add(LSTM(128, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(64))
    model.add(Dense(len(np.unique(y)), activation='softmax'))

    # Modeli derleyin
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    # Early stopping kullanın
    from keras.callbacks import EarlyStopping
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    # Modeli eğitin
    history = model.fit(X_train, to_categorical(y_train), epochs=50, batch_size=32, validation_data=(X_test, to_categorical(y_test)), callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 148/148 [==============================] - 20s 102ms/step - loss: 0.8585 - accuracy: 0.6142 - val_loss: 0.7092 - val_accuracy: 0.7217
# Epoch 2/50
# 148/148 [==============================] - 13s 88ms/step - loss: 0.6698 - accuracy: 0.7249 - val_loss: 0.6925 - val_accuracy: 0.7200
# Epoch 3/50
# 148/148 [==============================] - 13s 88ms/step - loss: 0.6119 - accuracy: 0.7530 - val_loss: 0.6845 - val_accuracy: 0.7403
# Epoch 4/50
# 148/148 [==============================] - 13s 88ms/step - loss: 0.5378 - accuracy: 0.7972 - val_loss: 0.7242 - val_accuracy: 0.7149
# Epoch 5/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.5100 - accuracy: 0.8044 - val_loss: 0.6829 - val_accuracy: 0.7386
# Epoch 6/50
# 148/148 [==============================] - 13s 88ms/step - loss: 0.5073 - accuracy: 0.7975 - val_loss: 0.6610 - val_accuracy: 0.7403
# Epoch 7/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.4318 - accuracy: 0.8334 - val_loss: 0.7415 - val_accuracy: 0.7208
# Epoch 8/50
# 148/148 [==============================] - 13s 88ms/step - loss: 0.3869 - accuracy: 0.8485 - val_loss: 0.7039 - val_accuracy: 0.7411
# Epoch 9/50
# 148/148 [==============================] - 13s 88ms/step - loss: 0.3590 - accuracy: 0.8582 - val_loss: 0.7199 - val_accuracy: 0.7394
# Epoch 10/50
# 148/148 [==============================] - 13s 88ms/step - loss: 0.4017 - accuracy: 0.8402 - val_loss: 0.7457 - val_accuracy: 0.7335
# Epoch 11/50
# 148/148 [==============================] - 13s 88ms/step - loss: 0.3795 - accuracy: 0.8557 - val_loss: 0.7339 - val_accuracy: 0.7293
# Epoch 1/50
# 148/148 [==============================] - 18s 102ms/step - loss: 0.8397 - accuracy: 0.6252 - val_loss: 0.7350 - val_accuracy: 0.6954
# Epoch 2/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.6604 - accuracy: 0.7359 - val_loss: 0.7044 - val_accuracy: 0.7098
# Epoch 3/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.5982 - accuracy: 0.7575 - val_loss: 0.7160 - val_accuracy: 0.6929
# Epoch 4/50
# 148/148 [==============================] - 13s 88ms/step - loss: 0.5318 - accuracy: 0.7905 - val_loss: 0.6763 - val_accuracy: 0.7462
# Epoch 5/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.5050 - accuracy: 0.8068 - val_loss: 0.6652 - val_accuracy: 0.7428
# Epoch 6/50
# 148/148 [==============================] - 13s 88ms/step - loss: 0.4391 - accuracy: 0.8332 - val_loss: 0.6389 - val_accuracy: 0.7563
# Epoch 7/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.3790 - accuracy: 0.8512 - val_loss: 0.7156 - val_accuracy: 0.7352
# Epoch 8/50
# 148/148 [==============================] - 13s 88ms/step - loss: 0.3637 - accuracy: 0.8618 - val_loss: 0.6905 - val_accuracy: 0.7513
# Epoch 9/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.3404 - accuracy: 0.8650 - val_loss: 0.7334 - val_accuracy: 0.7369
# Epoch 10/50
# 148/148 [==============================] - 13s 88ms/step - loss: 0.3746 - accuracy: 0.8538 - val_loss: 0.7216 - val_accuracy: 0.7352
# Epoch 11/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.3131 - accuracy: 0.8847 - val_loss: 0.8108 - val_accuracy: 0.7479
# Epoch 1/50
# 148/148 [==============================] - 18s 99ms/step - loss: 0.8569 - accuracy: 0.6257 - val_loss: 0.7585 - val_accuracy: 0.6918
# Epoch 2/50
# 148/148 [==============================] - 13s 88ms/step - loss: 0.6881 - accuracy: 0.7207 - val_loss: 0.6547 - val_accuracy: 0.7409
# Epoch 3/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.6087 - accuracy: 0.7643 - val_loss: 0.6749 - val_accuracy: 0.7257
# Epoch 4/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.5628 - accuracy: 0.7818 - val_loss: 0.7932 - val_accuracy: 0.6892
# Epoch 5/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.5237 - accuracy: 0.7975 - val_loss: 0.6106 - val_accuracy: 0.7536
# Epoch 6/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.4985 - accuracy: 0.8096 - val_loss: 0.6412 - val_accuracy: 0.7485
# Epoch 7/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.4567 - accuracy: 0.8233 - val_loss: 0.6299 - val_accuracy: 0.7671
# Epoch 8/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.3818 - accuracy: 0.8618 - val_loss: 0.7013 - val_accuracy: 0.7544
# Epoch 9/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.3998 - accuracy: 0.8447 - val_loss: 0.6274 - val_accuracy: 0.7460
# Epoch 10/50
# 148/148 [==============================] - 13s 88ms/step - loss: 0.3713 - accuracy: 0.8597 - val_loss: 0.6207 - val_accuracy: 0.7697
# Epoch 1/50
# 148/148 [==============================] - 18s 102ms/step - loss: 0.8540 - accuracy: 0.6229 - val_loss: 0.7186 - val_accuracy: 0.6994
# Epoch 2/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.6728 - accuracy: 0.7201 - val_loss: 0.7722 - val_accuracy: 0.6740
# Epoch 3/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.5978 - accuracy: 0.7609 - val_loss: 0.6665 - val_accuracy: 0.7290
# Epoch 4/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.5376 - accuracy: 0.7882 - val_loss: 0.6903 - val_accuracy: 0.7392
# Epoch 5/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.5016 - accuracy: 0.8094 - val_loss: 0.6654 - val_accuracy: 0.7367
# Epoch 6/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.4435 - accuracy: 0.8337 - val_loss: 0.7182 - val_accuracy: 0.7113
# Epoch 7/50
# 148/148 [==============================] - 13s 88ms/step - loss: 0.4028 - accuracy: 0.8447 - val_loss: 0.7979 - val_accuracy: 0.6833
# Epoch 8/50
# 148/148 [==============================] - 13s 88ms/step - loss: 0.4346 - accuracy: 0.8305 - val_loss: 0.7125 - val_accuracy: 0.6969
# Epoch 9/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.3912 - accuracy: 0.8517 - val_loss: 0.6738 - val_accuracy: 0.7519
# Epoch 10/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.3313 - accuracy: 0.8775 - val_loss: 0.6880 - val_accuracy: 0.7443
# Epoch 1/50
# 148/148 [==============================] - 18s 102ms/step - loss: 0.8403 - accuracy: 0.6119 - val_loss: 0.7385 - val_accuracy: 0.6749
# Epoch 2/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.6453 - accuracy: 0.7370 - val_loss: 0.7475 - val_accuracy: 0.7138
# Epoch 3/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.5854 - accuracy: 0.7611 - val_loss: 0.6915 - val_accuracy: 0.7197
# Epoch 4/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.5224 - accuracy: 0.7945 - val_loss: 0.6969 - val_accuracy: 0.7096
# Epoch 5/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.5134 - accuracy: 0.8026 - val_loss: 0.7203 - val_accuracy: 0.7206
# Epoch 6/50
# 148/148 [==============================] - 13s 90ms/step - loss: 0.4790 - accuracy: 0.8174 - val_loss: 0.7149 - val_accuracy: 0.7401
# Epoch 7/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.4881 - accuracy: 0.8079 - val_loss: 0.6674 - val_accuracy: 0.7494
# Epoch 8/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.4453 - accuracy: 0.8174 - val_loss: 0.6388 - val_accuracy: 0.7528
# Epoch 9/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.4418 - accuracy: 0.8244 - val_loss: 0.6736 - val_accuracy: 0.7544
# Epoch 10/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.4278 - accuracy: 0.8362 - val_loss: 0.8288 - val_accuracy: 0.6918
# Epoch 11/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.4801 - accuracy: 0.8165 - val_loss: 0.6189 - val_accuracy: 0.7629
# Epoch 12/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.4071 - accuracy: 0.8451 - val_loss: 0.6753 - val_accuracy: 0.7638
# Epoch 13/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.4493 - accuracy: 0.8218 - val_loss: 0.6289 - val_accuracy: 0.7655
# Epoch 14/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.3420 - accuracy: 0.8707 - val_loss: 1.1155 - val_accuracy: 0.6232
# Epoch 15/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.4207 - accuracy: 0.8405 - val_loss: 0.7158 - val_accuracy: 0.7375
# Epoch 16/50
# 148/148 [==============================] - 13s 89ms/step - loss: 0.3463 - accuracy: 0.8675 - val_loss: 0.7527 - val_accuracy: 0.7375

# %% [markdown]
# Modelin Değerlendirilmesi ve Sonuçların Raporlanması

# %%
# Model evaluation on test data
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Performance metrics calculation
accuracy = accuracy_score(y_test, y_pred_classes)
f1 = f1_score(y_test, y_pred_classes, average='weighted')
recall = recall_score(y_test, y_pred_classes, average='weighted')
precision = precision_score(y_test, y_pred_classes, average='weighted')
roc_auc = roc_auc_score(y_test, y_pred, average='weighted', multi_class='ovr')
mcc = matthews_corrcoef(y_test, y_pred_classes)

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred_classes)

# Results in tabular format
results = pd.DataFrame({
    'Accuracy': [accuracy],
    'F1 Score': [f1],
    'Recall': [recall],
    'Precision': [precision],
    'ROC AUC': [roc_auc],
    'MCC': [mcc]
})

print(results)
print('Confusion Matrix:')
print(conf_matrix)

# Training loss and accuracy plotting
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# ROC curve plotting for multiclass classification
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(len(le.classes_)):
    fpr[i], tpr[i], _ = roc_curve(y_test == i, y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
roc_auc = roc_auc_score(y_test, y_pred, average='macro', multi_class='ovr')

# Print the ROC AUC score
print("ROC AUC Score (Macro):", roc_auc)
# Out:
# 37/37 [==============================] - 2s 40ms/step
#    Accuracy  F1 Score    Recall  Precision   ROC AUC       MCC
# 0  0.762913  0.763886  0.762913   0.776338  0.906839  0.649359
# Confusion Matrix:
# [[322  75  19]
#  [ 42 309  23]
#  [ 46  75 270]]
# ROC AUC Score (Macro): 0.9066480363403912
