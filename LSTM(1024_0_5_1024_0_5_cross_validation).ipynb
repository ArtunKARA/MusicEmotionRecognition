# %% [markdown]
# <a href="https://colab.research.google.com/github/ArtunKARA/MusicEmotionRecognition/blob/main/LSTM(1024_0_5_1024_0_5_cross_validation).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ortam Kurulumu ve Gerekli Kütüphanelerin Yüklenmesi

# %%
# Gerekli kütüphanelerin yüklenmesi
# !pip install librosa
# !pip install tensorflow
# !pip install scikit-learn

import traceback

import os
import numpy as np
import pandas as pd
import librosa
import librosa.display
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, roc_auc_score, roc_curve, confusion_matrix, matthews_corrcoef, auc
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# Verilerin Hazırlanması

# %%
from google.colab import drive
drive.mount('/content/drive')

agresif_muzikler = '/content/drive/My Drive/Music Data/Agresif'
huzunlu_muzikler = '/content/drive/My Drive/Music Data/Hüzünlü'
neseli_muzikler = '/content/drive/My Drive/Music Data/Neşeli'

# Ses dosyalarını ve etiketlerini yükleyin
def load_data(klasor_yolu, label):
    X = []
    y = []
    for dosya in os.listdir(klasor_yolu):
        dosya_yolu = os.path.join(klasor_yolu, dosya)
        data, sample_rate = librosa.load(dosya_yolu)
        mels = librosa.feature.melspectrogram(y=data, sr=sample_rate)
        X.append(mels.T)  # .T ile transpose ederek (time, features) şekline getiriyoruz
        y.append(label)
    return X, y

# Verilerin yüklenmesi
X_agresif, y_agresif = load_data(agresif_muzikler, 'Agresif')
X_huzunlu, y_huzunlu = load_data(huzunlu_muzikler, 'Hüzünlü')
X_neseli, y_neseli = load_data(neseli_muzikler, 'Neşeli')

# Verileri birleştirin
X = X_agresif + X_huzunlu + X_neseli
y = y_agresif + y_huzunlu + y_neseli

# Etiketleri sayısal değerlere dönüştürün
le = LabelEncoder()
y = le.fit_transform(y)

# Pad sequences to have the same length
X_padded = pad_sequences(X, padding='post', dtype='float32')

# NumPy array'e dönüştürün
X_padded = np.array(X_padded)
y = np.array(y)

# Eğitim ve test setlerine ayırın
X_train, X_test, y_train, y_test = train_test_split(X_padded, y, test_size=0.2, random_state=42)
# Out:
# Mounted at /content/drive
# /usr/local/lib/python3.10/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=2048 is too large for input signal of length=1301
#   warnings.warn(

# %% [markdown]
#  Modelin Tanımlanması

# %%
from sklearn.model_selection import KFold
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from keras.preprocessing.sequence import pad_sequences

# Veri kümenizi K-fold cross validation için hazırlayın
kf = KFold(n_splits=5, shuffle=True)  # 5 parçaya ayırarak shuffle ederek

# Eğitim ve test setleri üzerinde K-fold cross validation yapın
for train_index, test_index in kf.split(X_padded):
    X_train, X_test = X_padded[train_index], X_padded[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Modeli tanımlayın
    model = Sequential()
    model.add(LSTM(1280, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
    model.add(Dropout(0.5))
    model.add(LSTM(1024))
    model.add(Dropout(0.5))
    model.add(Dense(len(np.unique(y)), activation='softmax'))

    # Modeli derleyin
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    # Early stopping kullanın
    from keras.callbacks import EarlyStopping
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    # Modeli eğitin
    history = model.fit(X_train, to_categorical(y_train), epochs=50, batch_size=32, validation_data=(X_test, to_categorical(y_test)), callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 148/148 [==============================] - 70s 439ms/step - loss: 0.8662 - accuracy: 0.6258 - val_loss: 0.6769 - val_accuracy: 0.7140
# Epoch 2/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.7265 - accuracy: 0.6963 - val_loss: 0.8784 - val_accuracy: 0.6455
# Epoch 3/50
# 148/148 [==============================] - 65s 441ms/step - loss: 0.8336 - accuracy: 0.6402 - val_loss: 0.6655 - val_accuracy: 0.7453
# Epoch 4/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.6981 - accuracy: 0.7177 - val_loss: 0.6344 - val_accuracy: 0.7547
# Epoch 5/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.5883 - accuracy: 0.7623 - val_loss: 0.5869 - val_accuracy: 0.7589
# Epoch 6/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.4967 - accuracy: 0.8078 - val_loss: 0.4843 - val_accuracy: 0.8054
# Epoch 7/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.4434 - accuracy: 0.8307 - val_loss: 0.5073 - val_accuracy: 0.8071
# Epoch 8/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.3589 - accuracy: 0.8646 - val_loss: 0.5838 - val_accuracy: 0.7851
# Epoch 9/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.3401 - accuracy: 0.8698 - val_loss: 0.4552 - val_accuracy: 0.8283
# Epoch 10/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.3014 - accuracy: 0.8878 - val_loss: 0.5275 - val_accuracy: 0.7944
# Epoch 11/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.2881 - accuracy: 0.8919 - val_loss: 0.4527 - val_accuracy: 0.8240
# Epoch 12/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.2350 - accuracy: 0.9115 - val_loss: 0.4825 - val_accuracy: 0.8359
# Epoch 13/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.1943 - accuracy: 0.9310 - val_loss: 0.4639 - val_accuracy: 0.8426
# Epoch 14/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.1837 - accuracy: 0.9321 - val_loss: 0.5511 - val_accuracy: 0.8249
# Epoch 15/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.1777 - accuracy: 0.9359 - val_loss: 0.4798 - val_accuracy: 0.8376
# Epoch 16/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.1750 - accuracy: 0.9363 - val_loss: 0.4931 - val_accuracy: 0.8198
# Epoch 1/50
# 148/148 [==============================] - 71s 456ms/step - loss: 0.8822 - accuracy: 0.6159 - val_loss: 0.7985 - val_accuracy: 0.6438
# Epoch 2/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.9044 - accuracy: 0.5956 - val_loss: 0.7769 - val_accuracy: 0.6582
# Epoch 3/50
# 148/148 [==============================] - 65s 443ms/step - loss: 0.8339 - accuracy: 0.6332 - val_loss: 0.6982 - val_accuracy: 0.7047
# Epoch 4/50
# 148/148 [==============================] - 65s 443ms/step - loss: 0.6806 - accuracy: 0.7187 - val_loss: 0.6223 - val_accuracy: 0.7377
# Epoch 5/50
# 148/148 [==============================] - 65s 443ms/step - loss: 0.6170 - accuracy: 0.7481 - val_loss: 0.5700 - val_accuracy: 0.7775
# Epoch 6/50
# 148/148 [==============================] - 66s 443ms/step - loss: 0.5451 - accuracy: 0.7786 - val_loss: 0.5338 - val_accuracy: 0.7893
# Epoch 7/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.5215 - accuracy: 0.7939 - val_loss: 0.5364 - val_accuracy: 0.7893
# Epoch 8/50
# 148/148 [==============================] - 65s 443ms/step - loss: 0.4791 - accuracy: 0.8074 - val_loss: 0.4777 - val_accuracy: 0.8105
# Epoch 9/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.4337 - accuracy: 0.8322 - val_loss: 0.5296 - val_accuracy: 0.7809
# Epoch 10/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.4292 - accuracy: 0.8356 - val_loss: 0.4746 - val_accuracy: 0.8156
# Epoch 11/50
# 148/148 [==============================] - 65s 443ms/step - loss: 0.3899 - accuracy: 0.8438 - val_loss: 0.4544 - val_accuracy: 0.8232
# Epoch 12/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.3545 - accuracy: 0.8652 - val_loss: 0.4856 - val_accuracy: 0.8063
# Epoch 13/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.3395 - accuracy: 0.8654 - val_loss: 0.5258 - val_accuracy: 0.8080
# Epoch 14/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.3192 - accuracy: 0.8764 - val_loss: 0.4843 - val_accuracy: 0.8384
# Epoch 15/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.3299 - accuracy: 0.8760 - val_loss: 0.5912 - val_accuracy: 0.8063
# Epoch 16/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.2958 - accuracy: 0.8902 - val_loss: 0.4095 - val_accuracy: 0.8528
# Epoch 17/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.2527 - accuracy: 0.9050 - val_loss: 0.4714 - val_accuracy: 0.8401
# Epoch 18/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.2742 - accuracy: 0.8980 - val_loss: 0.4585 - val_accuracy: 0.8299
# Epoch 19/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.2369 - accuracy: 0.9105 - val_loss: 0.4278 - val_accuracy: 0.8376
# Epoch 20/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.2141 - accuracy: 0.9187 - val_loss: 0.4797 - val_accuracy: 0.8333
# Epoch 21/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.2016 - accuracy: 0.9259 - val_loss: 0.4829 - val_accuracy: 0.8426
# Epoch 1/50
# 148/148 [==============================] - 70s 453ms/step - loss: 0.8797 - accuracy: 0.6155 - val_loss: 0.6903 - val_accuracy: 0.7053
# Epoch 2/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.6970 - accuracy: 0.7038 - val_loss: 0.6950 - val_accuracy: 0.7138
# Epoch 3/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.6284 - accuracy: 0.7383 - val_loss: 0.6027 - val_accuracy: 0.7570
# Epoch 4/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.5940 - accuracy: 0.7649 - val_loss: 0.6012 - val_accuracy: 0.7561
# Epoch 5/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.5776 - accuracy: 0.7696 - val_loss: 0.5895 - val_accuracy: 0.7858
# Epoch 6/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.5785 - accuracy: 0.7689 - val_loss: 0.6361 - val_accuracy: 0.7511
# Epoch 7/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.5218 - accuracy: 0.7969 - val_loss: 0.6259 - val_accuracy: 0.7502
# Epoch 8/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.5088 - accuracy: 0.8003 - val_loss: 0.5496 - val_accuracy: 0.7782
# Epoch 9/50
# 148/148 [==============================] - 65s 440ms/step - loss: 0.8126 - accuracy: 0.6475 - val_loss: 0.7112 - val_accuracy: 0.6876
# Epoch 10/50
# 148/148 [==============================] - 65s 440ms/step - loss: 0.6810 - accuracy: 0.7124 - val_loss: 0.6105 - val_accuracy: 0.7798
# Epoch 11/50
# 148/148 [==============================] - 65s 440ms/step - loss: 0.5555 - accuracy: 0.7730 - val_loss: 0.5672 - val_accuracy: 0.7697
# Epoch 12/50
# 148/148 [==============================] - 65s 440ms/step - loss: 0.4944 - accuracy: 0.8032 - val_loss: 0.5465 - val_accuracy: 0.7959
# Epoch 13/50
# 148/148 [==============================] - 65s 440ms/step - loss: 0.4374 - accuracy: 0.8343 - val_loss: 0.5047 - val_accuracy: 0.8027
# Epoch 14/50
# 148/148 [==============================] - 65s 440ms/step - loss: 0.3876 - accuracy: 0.8574 - val_loss: 0.5514 - val_accuracy: 0.8044
# Epoch 15/50
# 148/148 [==============================] - 65s 440ms/step - loss: 0.3984 - accuracy: 0.8485 - val_loss: 0.5927 - val_accuracy: 0.7756
# Epoch 16/50
# 148/148 [==============================] - 65s 440ms/step - loss: 0.3471 - accuracy: 0.8665 - val_loss: 0.4895 - val_accuracy: 0.8256
# Epoch 17/50
# 148/148 [==============================] - 65s 441ms/step - loss: 0.3065 - accuracy: 0.8834 - val_loss: 0.4782 - val_accuracy: 0.8323
# Epoch 18/50
# 148/148 [==============================] - 65s 439ms/step - loss: 0.2930 - accuracy: 0.8967 - val_loss: 0.5099 - val_accuracy: 0.8264
# Epoch 19/50
# 148/148 [==============================] - 65s 439ms/step - loss: 0.2500 - accuracy: 0.9105 - val_loss: 0.5045 - val_accuracy: 0.8222
# Epoch 20/50
# 148/148 [==============================] - 65s 439ms/step - loss: 0.2878 - accuracy: 0.8965 - val_loss: 0.4983 - val_accuracy: 0.8383
# Epoch 21/50
# 148/148 [==============================] - 65s 439ms/step - loss: 0.2252 - accuracy: 0.9226 - val_loss: 0.6648 - val_accuracy: 0.7985
# Epoch 22/50
# 148/148 [==============================] - 65s 439ms/step - loss: 0.2181 - accuracy: 0.9179 - val_loss: 0.4811 - val_accuracy: 0.8374
# Epoch 1/50
# 148/148 [==============================] - 70s 456ms/step - loss: 0.8603 - accuracy: 0.6322 - val_loss: 0.6729 - val_accuracy: 0.7130
# Epoch 2/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.6936 - accuracy: 0.7160 - val_loss: 0.6596 - val_accuracy: 0.7248
# Epoch 3/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.6844 - accuracy: 0.7131 - val_loss: 0.6291 - val_accuracy: 0.7468
# Epoch 4/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.6567 - accuracy: 0.7300 - val_loss: 0.6162 - val_accuracy: 0.7341
# Epoch 5/50
# 148/148 [==============================] - 65s 441ms/step - loss: 0.7406 - accuracy: 0.6890 - val_loss: 0.9161 - val_accuracy: 0.6503
# Epoch 6/50
# 148/148 [==============================] - 65s 441ms/step - loss: 0.6686 - accuracy: 0.7376 - val_loss: 0.6644 - val_accuracy: 0.7392
# Epoch 7/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.6194 - accuracy: 0.7548 - val_loss: 0.5791 - val_accuracy: 0.7697
# Epoch 8/50
# 148/148 [==============================] - 65s 441ms/step - loss: 0.6593 - accuracy: 0.7292 - val_loss: 0.5949 - val_accuracy: 0.7756
# Epoch 9/50
# 148/148 [==============================] - 65s 441ms/step - loss: 0.5017 - accuracy: 0.8064 - val_loss: 0.7467 - val_accuracy: 0.6740
# Epoch 10/50
# 148/148 [==============================] - 65s 441ms/step - loss: 0.4834 - accuracy: 0.8144 - val_loss: 0.5176 - val_accuracy: 0.7993
# Epoch 11/50
# 148/148 [==============================] - 65s 441ms/step - loss: 0.4294 - accuracy: 0.8407 - val_loss: 0.5044 - val_accuracy: 0.8129
# Epoch 12/50
# 148/148 [==============================] - 65s 440ms/step - loss: 0.3896 - accuracy: 0.8587 - val_loss: 0.4992 - val_accuracy: 0.8095
# Epoch 13/50
# 148/148 [==============================] - 65s 441ms/step - loss: 0.3332 - accuracy: 0.8769 - val_loss: 0.5836 - val_accuracy: 0.7951
# Epoch 14/50
# 148/148 [==============================] - 65s 440ms/step - loss: 0.3858 - accuracy: 0.8580 - val_loss: 0.5212 - val_accuracy: 0.8103
# Epoch 15/50
# 148/148 [==============================] - 65s 440ms/step - loss: 0.2884 - accuracy: 0.8925 - val_loss: 0.5330 - val_accuracy: 0.8247
# Epoch 16/50
# 148/148 [==============================] - 65s 441ms/step - loss: 0.2599 - accuracy: 0.8989 - val_loss: 0.4956 - val_accuracy: 0.8298
# Epoch 17/50
# 148/148 [==============================] - 65s 439ms/step - loss: 0.2440 - accuracy: 0.9113 - val_loss: 0.5291 - val_accuracy: 0.8044
# Epoch 18/50
# 148/148 [==============================] - 65s 440ms/step - loss: 0.2636 - accuracy: 0.9088 - val_loss: 0.5810 - val_accuracy: 0.7782
# Epoch 19/50
# 148/148 [==============================] - 65s 440ms/step - loss: 0.2360 - accuracy: 0.9101 - val_loss: 0.4510 - val_accuracy: 0.8501
# Epoch 20/50
# 148/148 [==============================] - 65s 440ms/step - loss: 0.1740 - accuracy: 0.9333 - val_loss: 0.4836 - val_accuracy: 0.8366
# Epoch 21/50
# 148/148 [==============================] - 65s 439ms/step - loss: 0.1588 - accuracy: 0.9437 - val_loss: 0.4228 - val_accuracy: 0.8594
# Epoch 22/50
# 148/148 [==============================] - 65s 440ms/step - loss: 0.1512 - accuracy: 0.9452 - val_loss: 0.4573 - val_accuracy: 0.8552
# Epoch 23/50
# 148/148 [==============================] - 65s 439ms/step - loss: 0.2180 - accuracy: 0.9219 - val_loss: 0.5454 - val_accuracy: 0.8264
# Epoch 24/50
# 148/148 [==============================] - 65s 439ms/step - loss: 0.1455 - accuracy: 0.9467 - val_loss: 0.5341 - val_accuracy: 0.8417
# Epoch 25/50
# 148/148 [==============================] - 65s 439ms/step - loss: 0.1320 - accuracy: 0.9524 - val_loss: 0.5727 - val_accuracy: 0.8476
# Epoch 26/50
# 148/148 [==============================] - 65s 439ms/step - loss: 0.1250 - accuracy: 0.9564 - val_loss: 0.5654 - val_accuracy: 0.8400
# Epoch 1/50
# 148/148 [==============================] - 71s 458ms/step - loss: 0.8811 - accuracy: 0.6284 - val_loss: 0.7699 - val_accuracy: 0.6545
# Epoch 2/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.7448 - accuracy: 0.6896 - val_loss: 0.7630 - val_accuracy: 0.6605
# Epoch 3/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.6633 - accuracy: 0.7237 - val_loss: 0.6909 - val_accuracy: 0.7223
# Epoch 4/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.6232 - accuracy: 0.7406 - val_loss: 0.6725 - val_accuracy: 0.7146
# Epoch 5/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.6294 - accuracy: 0.7412 - val_loss: 0.6222 - val_accuracy: 0.7485
# Epoch 6/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.6119 - accuracy: 0.7554 - val_loss: 0.5660 - val_accuracy: 0.7731
# Epoch 7/50
# 148/148 [==============================] - 65s 441ms/step - loss: 0.6418 - accuracy: 0.7395 - val_loss: 0.5985 - val_accuracy: 0.7570
# Epoch 8/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.5563 - accuracy: 0.7782 - val_loss: 0.5621 - val_accuracy: 0.7587
# Epoch 9/50
# 148/148 [==============================] - 65s 441ms/step - loss: 0.5794 - accuracy: 0.7778 - val_loss: 0.5985 - val_accuracy: 0.7511
# Epoch 10/50
# 148/148 [==============================] - 65s 442ms/step - loss: 0.4889 - accuracy: 0.8134 - val_loss: 0.4998 - val_accuracy: 0.8086
# Epoch 11/50
# 148/148 [==============================] - 65s 441ms/step - loss: 0.4361 - accuracy: 0.8320 - val_loss: 0.4854 - val_accuracy: 0.8036
# Epoch 12/50
# 148/148 [==============================] - 65s 441ms/step - loss: 0.3895 - accuracy: 0.8500 - val_loss: 0.4564 - val_accuracy: 0.8205
# Epoch 13/50
# 148/148 [==============================] - 65s 441ms/step - loss: 0.3650 - accuracy: 0.8648 - val_loss: 0.5455 - val_accuracy: 0.8010
# Epoch 14/50
# 148/148 [==============================] - 65s 441ms/step - loss: 0.3921 - accuracy: 0.8561 - val_loss: 0.4909 - val_accuracy: 0.8061
# Epoch 15/50
# 148/148 [==============================] - 65s 441ms/step - loss: 0.3363 - accuracy: 0.8754 - val_loss: 0.4494 - val_accuracy: 0.8323
# Epoch 16/50
# 148/148 [==============================] - 65s 441ms/step - loss: 0.3005 - accuracy: 0.8889 - val_loss: 0.4521 - val_accuracy: 0.8450
# Epoch 17/50
# 148/148 [==============================] - 65s 441ms/step - loss: 0.2936 - accuracy: 0.8847 - val_loss: 0.4790 - val_accuracy: 0.8129
# Epoch 18/50
# 148/148 [==============================] - 65s 441ms/step - loss: 0.2747 - accuracy: 0.9041 - val_loss: 0.4723 - val_accuracy: 0.8230
# Epoch 19/50
# 148/148 [==============================] - 65s 441ms/step - loss: 0.2175 - accuracy: 0.9171 - val_loss: 0.4565 - val_accuracy: 0.8425
# Epoch 20/50
# 148/148 [==============================] - 65s 440ms/step - loss: 0.1791 - accuracy: 0.9355 - val_loss: 0.4061 - val_accuracy: 0.8476
# Epoch 21/50
# 148/148 [==============================] - 65s 441ms/step - loss: 0.1567 - accuracy: 0.9452 - val_loss: 0.5303 - val_accuracy: 0.8307
# Epoch 22/50
# 148/148 [==============================] - 65s 440ms/step - loss: 0.1678 - accuracy: 0.9401 - val_loss: 0.4851 - val_accuracy: 0.8383
# Epoch 23/50
# 148/148 [==============================] - 65s 440ms/step - loss: 0.1355 - accuracy: 0.9503 - val_loss: 0.5072 - val_accuracy: 0.8357
# Epoch 24/50
# 148/148 [==============================] - 65s 440ms/step - loss: 0.1265 - accuracy: 0.9528 - val_loss: 0.4592 - val_accuracy: 0.8603
# Epoch 25/50
# 148/148 [==============================] - 65s 440ms/step - loss: 0.1186 - accuracy: 0.9551 - val_loss: 0.5140 - val_accuracy: 0.8561

# %% [markdown]
# Modelin Değerlendirilmesi

# %%
# Model evaluation on test data
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Performance metrics calculation
accuracy = accuracy_score(y_test, y_pred_classes)
f1 = f1_score(y_test, y_pred_classes, average='weighted')
recall = recall_score(y_test, y_pred_classes, average='weighted')
precision = precision_score(y_test, y_pred_classes, average='weighted')
roc_auc = roc_auc_score(y_test, y_pred, average='weighted', multi_class='ovr')
mcc = matthews_corrcoef(y_test, y_pred_classes)

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred_classes)

# Results in tabular format
results = pd.DataFrame({
    'Accuracy': [accuracy],
    'F1 Score': [f1],
    'Recall': [recall],
    'Precision': [precision],
    'ROC AUC': [roc_auc],
    'MCC': [mcc]
})

print(results)
print('Confusion Matrix:')
print(conf_matrix)

# Training loss and accuracy plotting
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# ROC curve plotting for multiclass classification
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(len(le.classes_)):
    fpr[i], tpr[i], _ = roc_curve(y_test == i, y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
roc_auc = roc_auc_score(y_test, y_pred, average='macro', multi_class='ovr')

# Print the ROC AUC score
print("ROC AUC Score (Macro):", roc_auc)
# Out:
# 37/37 [==============================] - 6s 167ms/step
#    Accuracy  F1 Score    Recall  Precision   ROC AUC       MCC
# 0  0.847587   0.84753  0.847587   0.850642  0.959864  0.772467
# Confusion Matrix:
# [[362  32  10]
#  [ 38 334  22]
#  [ 30  48 305]]
# ROC AUC Score (Macro): 0.9598399299521306
