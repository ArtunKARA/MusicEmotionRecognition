# %% [markdown]
# <a href="https://colab.research.google.com/github/ArtunKARA/MusicEmotionRecognition/blob/main/LSTM(128_0_5_64_0%2C8_64_0%2C8_128_0_5_cross_validation).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ortam Kurulumu ve Gerekli Kütüphanelerin Yüklenmesi

# %%
# Gerekli kütüphanelerin yüklenmesi
# !pip install librosa
# !pip install tensorflow
# !pip install scikit-learn

import traceback

import os
import numpy as np
import pandas as pd
import librosa
import librosa.display
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, roc_auc_score, roc_curve, confusion_matrix, matthews_corrcoef, auc
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# Verilerin Hazırlanması

# %%
from google.colab import drive
drive.mount('/content/drive')

agresif_muzikler = '/content/drive/My Drive/Music Data/Agresif'
huzunlu_muzikler = '/content/drive/My Drive/Music Data/Hüzünlü'
neseli_muzikler = '/content/drive/My Drive/Music Data/Neşeli'

# Ses dosyalarını ve etiketlerini yükleyin
def load_data(klasor_yolu, label):
    X = []
    y = []
    for dosya in os.listdir(klasor_yolu):
        dosya_yolu = os.path.join(klasor_yolu, dosya)
        data, sample_rate = librosa.load(dosya_yolu)
        mels = librosa.feature.melspectrogram(y=data, sr=sample_rate)
        X.append(mels.T)  # .T ile transpose ederek (time, features) şekline getiriyoruz
        y.append(label)
    return X, y

# Verilerin yüklenmesi
X_agresif, y_agresif = load_data(agresif_muzikler, 'Agresif')
X_huzunlu, y_huzunlu = load_data(huzunlu_muzikler, 'Hüzünlü')
X_neseli, y_neseli = load_data(neseli_muzikler, 'Neşeli')

# Verileri birleştirin
X = X_agresif + X_huzunlu + X_neseli
y = y_agresif + y_huzunlu + y_neseli

# Etiketleri sayısal değerlere dönüştürün
le = LabelEncoder()
y = le.fit_transform(y)

# Pad sequences to have the same length
X_padded = pad_sequences(X, padding='post', dtype='float32')

# NumPy array'e dönüştürün
X_padded = np.array(X_padded)
y = np.array(y)

# Eğitim ve test setlerine ayırın
X_train, X_test, y_train, y_test = train_test_split(X_padded, y, test_size=0.2, random_state=42)

# %% [markdown]
#  Modelin Tanımlanması

# %%
from sklearn.model_selection import KFold
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from keras.preprocessing.sequence import pad_sequences

# Veri kümenizi K-fold cross validation için hazırlayın
kf = KFold(n_splits=5, shuffle=True)  # 5 parçaya ayırarak shuffle ederek

# Eğitim ve test setleri üzerinde K-fold cross validation yapın
for train_index, test_index in kf.split(X_padded):
    X_train, X_test = X_padded[train_index], X_padded[test_index]
    y_train, y_test = y[train_index], y[test_index]

    # Modeli tanımlayın
    model = Sequential()
    model = Sequential()
    model.add(LSTM(128, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True))
    model.add(Dropout(0.5))

    model.add(LSTM(64, return_sequences=True))
    model.add(Dropout(0.8))

    model.add(LSTM(64, return_sequences=True))
    model.add(Dropout(0.8))

    model.add(LSTM(128))
    model.add(Dropout(0.5))
    model.add(Dense(len(np.unique(y)), activation='softmax'))

    # Modeli derleyin
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    # Early stopping kullanın
    from keras.callbacks import EarlyStopping
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

    # Modeli eğitin
    history = model.fit(X_train, to_categorical(y_train), epochs=100, batch_size=32, validation_data=(X_test, to_categorical(y_test)), callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 148/148 [==============================] - 35s 187ms/step - loss: 0.8989 - accuracy: 0.5892 - val_loss: 0.8147 - val_accuracy: 0.6641
# Epoch 2/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.7376 - accuracy: 0.7001 - val_loss: 0.7055 - val_accuracy: 0.7166
# Epoch 3/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.6708 - accuracy: 0.7361 - val_loss: 0.7156 - val_accuracy: 0.6997
# Epoch 4/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.6223 - accuracy: 0.7602 - val_loss: 0.6976 - val_accuracy: 0.7403
# Epoch 5/100
# 148/148 [==============================] - 25s 167ms/step - loss: 0.6037 - accuracy: 0.7723 - val_loss: 0.7105 - val_accuracy: 0.7217
# Epoch 6/100
# 148/148 [==============================] - 25s 167ms/step - loss: 0.5634 - accuracy: 0.7839 - val_loss: 0.8533 - val_accuracy: 0.6980
# Epoch 7/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.5908 - accuracy: 0.7763 - val_loss: 0.7024 - val_accuracy: 0.7352
# Epoch 8/100
# 148/148 [==============================] - 25s 167ms/step - loss: 0.5768 - accuracy: 0.7820 - val_loss: 0.7185 - val_accuracy: 0.7208
# Epoch 9/100
# 148/148 [==============================] - 25s 167ms/step - loss: 0.5251 - accuracy: 0.8049 - val_loss: 0.6540 - val_accuracy: 0.7462
# Epoch 10/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.5186 - accuracy: 0.8171 - val_loss: 0.6932 - val_accuracy: 0.7242
# Epoch 11/100
# 148/148 [==============================] - 25s 167ms/step - loss: 0.5173 - accuracy: 0.8019 - val_loss: 0.6718 - val_accuracy: 0.7699
# Epoch 12/100
# 148/148 [==============================] - 25s 167ms/step - loss: 0.4616 - accuracy: 0.8277 - val_loss: 0.6719 - val_accuracy: 0.7733
# Epoch 13/100
# 148/148 [==============================] - 25s 169ms/step - loss: 0.4485 - accuracy: 0.8360 - val_loss: 0.6838 - val_accuracy: 0.7614
# Epoch 14/100
# 148/148 [==============================] - 25s 167ms/step - loss: 0.4336 - accuracy: 0.8419 - val_loss: 0.6595 - val_accuracy: 0.7809
# Epoch 1/100
# 148/148 [==============================] - 33s 185ms/step - loss: 0.8745 - accuracy: 0.6154 - val_loss: 0.8876 - val_accuracy: 0.6582
# Epoch 2/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.7392 - accuracy: 0.7069 - val_loss: 0.7974 - val_accuracy: 0.7039
# Epoch 3/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.6917 - accuracy: 0.7253 - val_loss: 0.8222 - val_accuracy: 0.6937
# Epoch 4/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.6398 - accuracy: 0.7594 - val_loss: 0.7427 - val_accuracy: 0.7267
# Epoch 5/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.5815 - accuracy: 0.7801 - val_loss: 0.8046 - val_accuracy: 0.7310
# Epoch 6/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.5602 - accuracy: 0.7841 - val_loss: 0.7254 - val_accuracy: 0.7453
# Epoch 7/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.5245 - accuracy: 0.8108 - val_loss: 0.7411 - val_accuracy: 0.7386
# Epoch 8/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.5112 - accuracy: 0.8087 - val_loss: 0.6839 - val_accuracy: 0.7521
# Epoch 9/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.6021 - accuracy: 0.7759 - val_loss: 0.7195 - val_accuracy: 0.7174
# Epoch 10/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.5122 - accuracy: 0.8080 - val_loss: 0.7184 - val_accuracy: 0.7614
# Epoch 11/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.4433 - accuracy: 0.8343 - val_loss: 0.7193 - val_accuracy: 0.7538
# Epoch 12/100
# 148/148 [==============================] - 25s 167ms/step - loss: 0.4774 - accuracy: 0.8207 - val_loss: 0.7736 - val_accuracy: 0.7496
# Epoch 13/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.4382 - accuracy: 0.8468 - val_loss: 0.7276 - val_accuracy: 0.7513
# Epoch 1/100
# 148/148 [==============================] - 33s 182ms/step - loss: 0.8930 - accuracy: 0.6056 - val_loss: 0.7533 - val_accuracy: 0.6986
# Epoch 2/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.7398 - accuracy: 0.7038 - val_loss: 0.7541 - val_accuracy: 0.7113
# Epoch 3/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.6683 - accuracy: 0.7425 - val_loss: 0.7156 - val_accuracy: 0.7273
# Epoch 4/100
# 148/148 [==============================] - 25s 167ms/step - loss: 0.6329 - accuracy: 0.7543 - val_loss: 0.7458 - val_accuracy: 0.7384
# Epoch 5/100
# 148/148 [==============================] - 25s 167ms/step - loss: 0.5757 - accuracy: 0.7835 - val_loss: 0.6923 - val_accuracy: 0.7401
# Epoch 6/100
# 148/148 [==============================] - 25s 167ms/step - loss: 0.5897 - accuracy: 0.7755 - val_loss: 0.7318 - val_accuracy: 0.7180
# Epoch 7/100
# 148/148 [==============================] - 25s 167ms/step - loss: 0.5790 - accuracy: 0.7806 - val_loss: 0.7109 - val_accuracy: 0.7426
# Epoch 8/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.5366 - accuracy: 0.7992 - val_loss: 0.6886 - val_accuracy: 0.7443
# Epoch 9/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.5167 - accuracy: 0.8106 - val_loss: 0.7404 - val_accuracy: 0.7511
# Epoch 10/100
# 148/148 [==============================] - 25s 167ms/step - loss: 0.5000 - accuracy: 0.8170 - val_loss: 0.7628 - val_accuracy: 0.7358
# Epoch 11/100
# 148/148 [==============================] - 25s 167ms/step - loss: 0.5556 - accuracy: 0.7977 - val_loss: 0.6609 - val_accuracy: 0.7663
# Epoch 12/100
# 148/148 [==============================] - 25s 167ms/step - loss: 0.4802 - accuracy: 0.8275 - val_loss: 0.6901 - val_accuracy: 0.7595
# Epoch 13/100
# 148/148 [==============================] - 25s 167ms/step - loss: 0.4524 - accuracy: 0.8311 - val_loss: 0.6079 - val_accuracy: 0.7578
# Epoch 14/100
# 148/148 [==============================] - 25s 167ms/step - loss: 0.4307 - accuracy: 0.8443 - val_loss: 0.7589 - val_accuracy: 0.7604
# Epoch 15/100
# 148/148 [==============================] - 25s 167ms/step - loss: 0.4131 - accuracy: 0.8546 - val_loss: 0.6284 - val_accuracy: 0.7875
# Epoch 16/100
# 148/148 [==============================] - 25s 167ms/step - loss: 0.3592 - accuracy: 0.8705 - val_loss: 0.7584 - val_accuracy: 0.7663
# Epoch 17/100
# 148/148 [==============================] - 25s 167ms/step - loss: 0.3702 - accuracy: 0.8671 - val_loss: 0.6750 - val_accuracy: 0.7849
# Epoch 18/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.3532 - accuracy: 0.8790 - val_loss: 0.7301 - val_accuracy: 0.7756
# Epoch 1/100
# 148/148 [==============================] - 33s 182ms/step - loss: 0.9095 - accuracy: 0.5931 - val_loss: 0.8019 - val_accuracy: 0.6774
# Epoch 2/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.7297 - accuracy: 0.7078 - val_loss: 0.7513 - val_accuracy: 0.7248
# Epoch 3/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.6524 - accuracy: 0.7480 - val_loss: 1.0408 - val_accuracy: 0.6503
# Epoch 4/100
# 148/148 [==============================] - 25s 167ms/step - loss: 0.6210 - accuracy: 0.7579 - val_loss: 0.8035 - val_accuracy: 0.7087
# Epoch 5/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.5786 - accuracy: 0.7893 - val_loss: 0.7310 - val_accuracy: 0.7155
# Epoch 6/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.5631 - accuracy: 0.7948 - val_loss: 0.7101 - val_accuracy: 0.7460
# Epoch 7/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.4978 - accuracy: 0.8195 - val_loss: 0.7881 - val_accuracy: 0.7612
# Epoch 8/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.4928 - accuracy: 0.8115 - val_loss: 0.8327 - val_accuracy: 0.7206
# Epoch 9/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.5125 - accuracy: 0.8106 - val_loss: 0.7807 - val_accuracy: 0.7384
# Epoch 10/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.5070 - accuracy: 0.8053 - val_loss: 0.7067 - val_accuracy: 0.7528
# Epoch 11/100
# 148/148 [==============================] - 25s 167ms/step - loss: 0.4363 - accuracy: 0.8386 - val_loss: 0.7626 - val_accuracy: 0.7290
# Epoch 12/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.4217 - accuracy: 0.8424 - val_loss: 0.7029 - val_accuracy: 0.7782
# Epoch 13/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.4147 - accuracy: 0.8534 - val_loss: 0.7166 - val_accuracy: 0.7671
# Epoch 14/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.3808 - accuracy: 0.8608 - val_loss: 0.7400 - val_accuracy: 0.7731
# Epoch 15/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.4138 - accuracy: 0.8479 - val_loss: 0.8019 - val_accuracy: 0.7477
# Epoch 16/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.4364 - accuracy: 0.8506 - val_loss: 0.6792 - val_accuracy: 0.7544
# Epoch 17/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.3967 - accuracy: 0.8644 - val_loss: 0.7089 - val_accuracy: 0.7561
# Epoch 18/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.3638 - accuracy: 0.8741 - val_loss: 0.9983 - val_accuracy: 0.6977
# Epoch 19/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.3699 - accuracy: 0.8713 - val_loss: 0.6886 - val_accuracy: 0.7739
# Epoch 20/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.3244 - accuracy: 0.8895 - val_loss: 0.7056 - val_accuracy: 0.7646
# Epoch 21/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.3044 - accuracy: 0.8946 - val_loss: 0.7819 - val_accuracy: 0.7663
# Epoch 1/100
# 148/148 [==============================] - 33s 183ms/step - loss: 0.8913 - accuracy: 0.6140 - val_loss: 0.8445 - val_accuracy: 0.6740
# Epoch 2/100
# 148/148 [==============================] - 25s 169ms/step - loss: 0.7360 - accuracy: 0.7017 - val_loss: 0.7988 - val_accuracy: 0.6960
# Epoch 3/100
# 148/148 [==============================] - 25s 169ms/step - loss: 0.6630 - accuracy: 0.7412 - val_loss: 0.7305 - val_accuracy: 0.7155
# Epoch 4/100
# 148/148 [==============================] - 25s 169ms/step - loss: 0.6867 - accuracy: 0.7298 - val_loss: 0.7293 - val_accuracy: 0.7146
# Epoch 5/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.7023 - accuracy: 0.7158 - val_loss: 0.9722 - val_accuracy: 0.6562
# Epoch 6/100
# 148/148 [==============================] - 25s 169ms/step - loss: 0.6959 - accuracy: 0.7361 - val_loss: 0.6991 - val_accuracy: 0.7290
# Epoch 7/100
# 148/148 [==============================] - 25s 169ms/step - loss: 0.6277 - accuracy: 0.7611 - val_loss: 0.8126 - val_accuracy: 0.6969
# Epoch 8/100
# 148/148 [==============================] - 25s 169ms/step - loss: 0.5773 - accuracy: 0.7821 - val_loss: 0.6657 - val_accuracy: 0.7604
# Epoch 9/100
# 148/148 [==============================] - 25s 169ms/step - loss: 0.6222 - accuracy: 0.7645 - val_loss: 0.6304 - val_accuracy: 0.7680
# Epoch 10/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.5941 - accuracy: 0.7782 - val_loss: 0.8692 - val_accuracy: 0.5334
# Epoch 11/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.7729 - accuracy: 0.6775 - val_loss: 0.7340 - val_accuracy: 0.7214
# Epoch 12/100
# 148/148 [==============================] - 25s 169ms/step - loss: 0.5888 - accuracy: 0.7736 - val_loss: 0.6599 - val_accuracy: 0.7434
# Epoch 13/100
# 148/148 [==============================] - 25s 169ms/step - loss: 0.7141 - accuracy: 0.7330 - val_loss: 0.6390 - val_accuracy: 0.7621
# Epoch 14/100
# 148/148 [==============================] - 25s 168ms/step - loss: 0.5917 - accuracy: 0.7776 - val_loss: 0.6344 - val_accuracy: 0.7587

# %% [markdown]
# Modelin Değerlendirilmesi

# %%
# Model evaluation on test data
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Performance metrics calculation
accuracy = accuracy_score(y_test, y_pred_classes)
f1 = f1_score(y_test, y_pred_classes, average='weighted')
recall = recall_score(y_test, y_pred_classes, average='weighted')
precision = precision_score(y_test, y_pred_classes, average='weighted')
roc_auc = roc_auc_score(y_test, y_pred, average='weighted', multi_class='ovr')
mcc = matthews_corrcoef(y_test, y_pred_classes)

# Confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred_classes)

# Results in tabular format
results = pd.DataFrame({
    'Accuracy': [accuracy],
    'F1 Score': [f1],
    'Recall': [recall],
    'Precision': [precision],
    'ROC AUC': [roc_auc],
    'MCC': [mcc]
})

print(results)
print('Confusion Matrix:')
print(conf_matrix)

# Training loss and accuracy plotting
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy vs Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# ROC curve plotting for multiclass classification
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(len(le.classes_)):
    fpr[i], tpr[i], _ = roc_curve(y_test == i, y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
roc_auc = roc_auc_score(y_test, y_pred, average='macro', multi_class='ovr')

# Print the ROC AUC score
print("ROC AUC Score (Macro):", roc_auc)
# Out:
# 37/37 [==============================] - 4s 77ms/step
#    Accuracy  F1 Score    Recall  Precision  ROC AUC       MCC
# 0  0.767993  0.768268  0.767993   0.770056  0.89658  0.652325
# Confusion Matrix:
# [[286  55  37]
#  [ 35 317  49]
#  [ 34  64 304]]
# ROC AUC Score (Macro): 0.8968023965356737
